# %% [markdown]
# ## POU-approximation with initial guess of partition of unity

# %%
import numpy as np
import jax
import jax.numpy as jnp
import sys
import matplotlib.pyplot as plt

project_root = "/mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project" 
sys.path.append(project_root)

from utils.pou_utils import toy_func_2, Normalizer, visualize_final_approximation
from model.rbf_pou import RBFPOUNet
from train.train_pou_rbf import train_two_phase_lsgd_rbf

# %%
x_raw = np.linspace(0, 4, 300)  
y_true = np.array(toy_func_2(x_raw))  

# plot
plt.figure(figsize=(5, 3))
plt.plot(x_raw, y_true, label="Ground Truth (Toy Function)", color="black")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Toy Function")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Number of partition = 5 on interval [0,4]

# %%
key = jax.random.PRNGKey(0)
num_partition = 5
model = RBFPOUNet(input_dim=1, num_centers=num_partition, key=key)
# Initialization
x_train_raw = jnp.linspace(0, 4, 200)  # original input
y_train = toy_func_2(x_train_raw)

normalizer = Normalizer(min_val=x_train_raw.min(), max_val=x_train_raw.max())
x_train = normalizer.transform(x_train_raw)  # normalized to  [0,1]

final_params = train_two_phase_lsgd_rbf(
    model,
    x_train,
    y_train,
    num_epochs_phase1=61,
    num_epochs_phase2=51,
    lambda_reg=0.2,
    rho=0.99,
    n_stag=100,
    lr_phase1=0.01,
    lr_phase2=0.005,
    fixed_pou=None
)
# Out:
# Debug: partitions_np.shape (200, 5)
# Debug: N = 200, C = 5
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 0, Loss: 0.268000, λ: 0.200000
# Phase 1, Epoch 10, Loss: 0.132336, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 20, Loss: 0.028243, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 30, Loss: 0.012424, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 40, Loss: 0.009433, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 50, Loss: 0.002513, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 60, Loss: 0.001804, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 0, Loss: 0.000306, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 10, Loss: 0.000136, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 20, Loss: 0.000125, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 30, Loss: 0.000118, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 40, Loss: 0.000121, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 50, Loss: 0.000111, λ: 0.000000

# %%
x_train = normalizer.transform(x_train_raw)

visualize_final_approximation(
    model=model,
    params=final_params,
    x_train=x_train,
    y_train=y_train,
    normalizer=normalizer,
    ground_truth_fn=toy_func_2,
    save_path=None,   
    show_partitions=True,
    title="RBF-POU Approximation"
)
# Out:
# Debug: partitions_np.shape (200, 5)
# Debug: N = 200, C = 5
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/utils/pou_utils.py:187: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## number of partitions = 15 on a larger interval [0,8]

# %%
key = jax.random.PRNGKey(0)
num_partition = 15
model = RBFPOUNet(input_dim=1, num_centers=15, width_val=0.02, key=key)
# Initialization
x_train_raw = jnp.linspace(0, 8, 300)  # original input
y_train = toy_func_2(x_train_raw)

normalizer = Normalizer(min_val=x_train_raw.min(), max_val=x_train_raw.max())
x_train = normalizer.transform(x_train_raw)  # normalized to  [0,1]

final_params = train_two_phase_lsgd_rbf(
    model,
    x_train,
    y_train,
    num_epochs_phase1=1000,
    num_epochs_phase2=500,
    lambda_reg=0.05,
    rho=0.99,
    n_stag=100,
    lr_phase1=0.001,
    lr_phase2=0.0005,
    fixed_pou=True
)
# Out:
# Debug: partitions_np.shape (300, 15)
# Debug: N = 300, C = 15
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 0, Loss: 0.032786, λ: 0.050000
# Phase 1, Epoch 10, Loss: 0.025260, λ: 0.050000
# Phase 1, Epoch 20, Loss: 0.022163, λ: 0.050000
# Phase 1, Epoch 30, Loss: 0.021351, λ: 0.050000
# Phase 1, Epoch 40, Loss: 0.020573, λ: 0.050000
# Phase 1, Epoch 50, Loss: 0.020291, λ: 0.050000
# Phase 1, Epoch 60, Loss: 0.020213, λ: 0.050000
# Phase 1, Epoch 70, Loss: 0.020182, λ: 0.050000
# Phase 1, Epoch 80, Loss: 0.020067, λ: 0.050000
# Phase 1, Epoch 90, Loss: 0.020026, λ: 0.050000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 100, Loss: 0.020032, λ: 0.050000
# Phase 1, Epoch 110, Loss: 0.020014, λ: 0.050000
# Phase 1, Epoch 120, Loss: 0.020025, λ: 0.050000
# Phase 1, Epoch 130, Loss: 0.020089, λ: 0.050000
# Phase 1, Epoch 140, Loss: 0.020054, λ: 0.050000
# Phase 1, Epoch 150, Loss: 0.020001, λ: 0.050000
# Phase 1, Epoch 160, Loss: 0.019969, λ: 0.050000
# Phase 1, Epoch 170, Loss: 0.020093, λ: 0.050000
# Phase 1, Epoch 180, Loss: 0.019963, λ: 0.050000
# Phase 1, Epoch 190, Loss: 0.019993, λ: 0.050000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 200, Loss: 0.019967, λ: 0.050000
# Phase 1, Epoch 210, Loss: 0.019954, λ: 0.050000
# Phase 1, Epoch 220, Loss: 0.019946, λ: 0.050000
# Phase 1, Epoch 230, Loss: 0.019960, λ: 0.050000
# Phase 1, Epoch 240, Loss: 0.019949, λ: 0.050000
# Phase 1, Epoch 250, Loss: 0.020011, λ: 0.050000
# Phase 1, Epoch 260, Loss: 0.019992, λ: 0.050000
# Phase 1, Epoch 270, Loss: 0.020028, λ: 0.050000
# Phase 1, Epoch 280, Loss: 0.019993, λ: 0.050000
# Phase 1, Epoch 290, Loss: 0.019968, λ: 0.050000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 300, Loss: 0.019949, λ: 0.050000
# Phase 1, Epoch 310, Loss: 0.020143, λ: 0.050000
# Phase 1, Epoch 320, Loss: 0.019913, λ: 0.050000
# Phase 1, Epoch 330, Loss: 0.019895, λ: 0.050000
# Phase 1, Epoch 340, Loss: 0.019963, λ: 0.050000
# Phase 1, Epoch 350, Loss: 0.019963, λ: 0.050000
# Phase 1, Epoch 360, Loss: 0.019912, λ: 0.050000
# Phase 1, Epoch 370, Loss: 0.019887, λ: 0.050000
# Phase 1, Epoch 380, Loss: 0.019939, λ: 0.050000
# Phase 1, Epoch 390, Loss: 0.019925, λ: 0.050000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 400, Loss: 0.019932, λ: 0.050000
# Phase 1, Epoch 410, Loss: 0.020028, λ: 0.050000
# Phase 1, Epoch 420, Loss: 0.020032, λ: 0.050000
# Phase 1, Epoch 430, Loss: 0.019826, λ: 0.050000
# Phase 1, Epoch 440, Loss: 0.019900, λ: 0.050000
# Phase 1, Epoch 450, Loss: 0.019775, λ: 0.050000
# Phase 1, Epoch 460, Loss: 0.019774, λ: 0.050000
# Phase 1, Epoch 470, Loss: 0.019721, λ: 0.050000
# Phase 1, Epoch 480, Loss: 0.019692, λ: 0.050000
# Phase 1, Epoch 490, Loss: 0.019650, λ: 0.050000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 500, Loss: 0.017979, λ: 0.050000
# Phase 1, Epoch 510, Loss: 0.017494, λ: 0.050000
# Phase 1, Epoch 520, Loss: 0.017101, λ: 0.050000
# Phase 1, Epoch 530, Loss: 0.017051, λ: 0.050000
# Phase 1, Epoch 540, Loss: 0.017101, λ: 0.050000
# Phase 1, Epoch 550, Loss: 0.017047, λ: 0.050000
# Phase 1, Epoch 560, Loss: 0.017057, λ: 0.050000
# Phase 1, Epoch 570, Loss: 0.017005, λ: 0.050000
# Phase 1, Epoch 580, Loss: 0.016992, λ: 0.050000
# Phase 1, Epoch 590, Loss: 0.016993, λ: 0.050000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 600, Loss: 0.017196, λ: 0.050000
# Phase 1, Epoch 610, Loss: 0.017052, λ: 0.050000
# Phase 1, Epoch 620, Loss: 0.016975, λ: 0.050000
# Phase 1, Epoch 630, Loss: 0.016995, λ: 0.050000
# Phase 1, Epoch 640, Loss: 0.017135, λ: 0.050000
# Phase 1, Epoch 650, Loss: 0.017037, λ: 0.050000
# Phase 1, Epoch 660, Loss: 0.016984, λ: 0.050000
# Phase 1, Epoch 670, Loss: 0.017156, λ: 0.050000
# Phase 1, Epoch 680, Loss: 0.017151, λ: 0.050000
# Phase 1, Epoch 690, Loss: 0.017120, λ: 0.050000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 700, Loss: 0.016981, λ: 0.050000
# Phase 1, Epoch 710, Loss: 0.017034, λ: 0.050000
# Phase 1, Epoch 720, Loss: 0.017059, λ: 0.050000
# Phase 1, Epoch 730, Loss: 0.016994, λ: 0.050000
# Phase 1, Epoch 740, Loss: 0.017024, λ: 0.050000
# Phase 1, Epoch 750, Loss: 0.017094, λ: 0.050000
# Phase 1, Epoch 760, Loss: 0.017043, λ: 0.050000
# Phase 1, Epoch 770, Loss: 0.017008, λ: 0.050000
# Phase 1, Epoch 780, Loss: 0.017023, λ: 0.049500
# Phase 1, Epoch 790, Loss: 0.017226, λ: 0.049500
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 800, Loss: 0.017079, λ: 0.049500
# Phase 1, Epoch 810, Loss: 0.017002, λ: 0.049500
# Phase 1, Epoch 820, Loss: 0.016973, λ: 0.049500
# Phase 1, Epoch 830, Loss: 0.016992, λ: 0.049500
# Phase 1, Epoch 840, Loss: 0.016979, λ: 0.049500
# Phase 1, Epoch 850, Loss: 0.017079, λ: 0.049500
# Phase 1, Epoch 860, Loss: 0.017095, λ: 0.049500
# Phase 1, Epoch 870, Loss: 0.017041, λ: 0.049500
# Phase 1, Epoch 880, Loss: 0.016969, λ: 0.049005
# Phase 1, Epoch 890, Loss: 0.017033, λ: 0.049005
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 900, Loss: 0.016998, λ: 0.049005
# Phase 1, Epoch 910, Loss: 0.017020, λ: 0.049005
# Phase 1, Epoch 920, Loss: 0.017099, λ: 0.049005
# Phase 1, Epoch 930, Loss: 0.017039, λ: 0.049005
# Phase 1, Epoch 940, Loss: 0.017000, λ: 0.049005
# Phase 1, Epoch 950, Loss: 0.016996, λ: 0.049005
# Phase 1, Epoch 960, Loss: 0.017023, λ: 0.049005
# Phase 1, Epoch 970, Loss: 0.016984, λ: 0.049005
# Phase 1, Epoch 980, Loss: 0.017024, λ: 0.048515
# Phase 1, Epoch 990, Loss: 0.017011, λ: 0.048515
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 0, Loss: 0.016966, λ: 0.000000
# Phase 2, Epoch 10, Loss: 0.017010, λ: 0.000000
# Phase 2, Epoch 20, Loss: 0.016966, λ: 0.000000
# Phase 2, Epoch 30, Loss: 0.016937, λ: 0.000000
# Phase 2, Epoch 40, Loss: 0.016930, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 50, Loss: 0.016942, λ: 0.000000
# Phase 2, Epoch 60, Loss: 0.016964, λ: 0.000000
# Phase 2, Epoch 70, Loss: 0.017054, λ: 0.000000
# Phase 2, Epoch 80, Loss: 0.016973, λ: 0.000000
# Phase 2, Epoch 90, Loss: 0.016984, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 100, Loss: 0.016973, λ: 0.000000
# Phase 2, Epoch 110, Loss: 0.017008, λ: 0.000000
# Phase 2, Epoch 120, Loss: 0.016985, λ: 0.000000
# Phase 2, Epoch 130, Loss: 0.016948, λ: 0.000000
# Phase 2, Epoch 140, Loss: 0.016953, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 150, Loss: 0.016970, λ: 0.000000
# Phase 2, Epoch 160, Loss: 0.016967, λ: 0.000000
# Phase 2, Epoch 170, Loss: 0.017016, λ: 0.000000
# Phase 2, Epoch 180, Loss: 0.016937, λ: 0.000000
# Phase 2, Epoch 190, Loss: 0.016933, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 200, Loss: 0.016953, λ: 0.000000
# Phase 2, Epoch 210, Loss: 0.016971, λ: 0.000000
# Phase 2, Epoch 220, Loss: 0.016940, λ: 0.000000
# Phase 2, Epoch 230, Loss: 0.016936, λ: 0.000000
# Phase 2, Epoch 240, Loss: 0.016985, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 250, Loss: 0.016970, λ: 0.000000
# Phase 2, Epoch 260, Loss: 0.016970, λ: 0.000000
# Phase 2, Epoch 270, Loss: 0.016958, λ: 0.000000
# Phase 2, Epoch 280, Loss: 0.016972, λ: 0.000000
# Phase 2, Epoch 290, Loss: 0.016945, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 300, Loss: 0.016949, λ: 0.000000
# Phase 2, Epoch 310, Loss: 0.017025, λ: 0.000000
# Phase 2, Epoch 320, Loss: 0.016983, λ: 0.000000
# Phase 2, Epoch 330, Loss: 0.016937, λ: 0.000000
# Phase 2, Epoch 340, Loss: 0.016973, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 350, Loss: 0.016943, λ: 0.000000
# Phase 2, Epoch 360, Loss: 0.016963, λ: 0.000000
# Phase 2, Epoch 370, Loss: 0.017004, λ: 0.000000
# Phase 2, Epoch 380, Loss: 0.016997, λ: 0.000000
# Phase 2, Epoch 390, Loss: 0.016956, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 400, Loss: 0.016949, λ: 0.000000
# Phase 2, Epoch 410, Loss: 0.016969, λ: 0.000000
# Phase 2, Epoch 420, Loss: 0.016951, λ: 0.000000
# Phase 2, Epoch 430, Loss: 0.016939, λ: 0.000000
# Phase 2, Epoch 440, Loss: 0.016994, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 450, Loss: 0.016928, λ: 0.000000
# Phase 2, Epoch 460, Loss: 0.016933, λ: 0.000000
# Phase 2, Epoch 470, Loss: 0.016941, λ: 0.000000
# Phase 2, Epoch 480, Loss: 0.016999, λ: 0.000000
# Phase 2, Epoch 490, Loss: 0.016930, λ: 0.000000

# %%
x_train = normalizer.transform(x_train_raw)

visualize_final_approximation(
    model=model,
    params=final_params,
    x_train=x_train,
    y_train=y_train,
    normalizer=normalizer,
    ground_truth_fn=toy_func_2,
    save_path=None,   
    show_partitions=True,
    title="RBF-POU Approximation"
)
# Out:
# Debug: partitions_np.shape (300, 15)
# Debug: N = 300, C = 15
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/utils/pou_utils.py:187: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Number of partitions = 5 on the interval [0,8]

# %%
key = jax.random.PRNGKey(0)
num_partition = 5
model = RBFPOUNet(input_dim=1, num_centers=5, width_val=0.05, key=key)
# Initialization
x_train_raw = jnp.linspace(0, 8, 300)  # original input
y_train = toy_func_2(x_train_raw)

normalizer = Normalizer(min_val=x_train_raw.min(), max_val=x_train_raw.max())
x_train = normalizer.transform(x_train_raw)  # normalized to  [0,1]

final_params = train_two_phase_lsgd_rbf(
    model,
    x_train,
    y_train,
    num_epochs_phase1=500,
    num_epochs_phase2=100,
    lambda_reg=0.2,
    rho=0.99,
    n_stag=100,
    lr_phase1=0.001,
    lr_phase2=0.0005,
    fixed_pou=True
)
# Out:
# Debug: partitions_np.shape (300, 5)
# Debug: N = 300, C = 5
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 0, Loss: 0.323070, λ: 0.200000
# Phase 1, Epoch 10, Loss: 0.298748, λ: 0.200000
# Phase 1, Epoch 20, Loss: 0.295733, λ: 0.200000
# Phase 1, Epoch 30, Loss: 0.290892, λ: 0.200000
# Phase 1, Epoch 40, Loss: 0.287884, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 50, Loss: 0.285101, λ: 0.200000
# Phase 1, Epoch 60, Loss: 0.283256, λ: 0.200000
# Phase 1, Epoch 70, Loss: 0.282212, λ: 0.200000
# Phase 1, Epoch 80, Loss: 0.281782, λ: 0.200000
# Phase 1, Epoch 90, Loss: 0.281674, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 100, Loss: 0.281627, λ: 0.200000
# Phase 1, Epoch 110, Loss: 0.281559, λ: 0.200000
# Phase 1, Epoch 120, Loss: 0.281465, λ: 0.200000
# Phase 1, Epoch 130, Loss: 0.281074, λ: 0.200000
# Phase 1, Epoch 140, Loss: 0.272777, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 150, Loss: 0.245341, λ: 0.200000
# Phase 1, Epoch 160, Loss: 0.237889, λ: 0.200000
# Phase 1, Epoch 170, Loss: 0.236119, λ: 0.200000
# Phase 1, Epoch 180, Loss: 0.235061, λ: 0.200000
# Phase 1, Epoch 190, Loss: 0.234276, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 200, Loss: 0.233753, λ: 0.200000
# Phase 1, Epoch 210, Loss: 0.232726, λ: 0.200000
# Phase 1, Epoch 220, Loss: 0.229893, λ: 0.200000
# Phase 1, Epoch 230, Loss: 0.220764, λ: 0.200000
# Phase 1, Epoch 240, Loss: 0.207069, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 250, Loss: 0.203013, λ: 0.200000
# Phase 1, Epoch 260, Loss: 0.201492, λ: 0.200000
# Phase 1, Epoch 270, Loss: 0.200564, λ: 0.200000
# Phase 1, Epoch 280, Loss: 0.200171, λ: 0.200000
# Phase 1, Epoch 290, Loss: 0.199880, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 300, Loss: 0.199709, λ: 0.200000
# Phase 1, Epoch 310, Loss: 0.199614, λ: 0.200000
# Phase 1, Epoch 320, Loss: 0.199543, λ: 0.200000
# Phase 1, Epoch 330, Loss: 0.199485, λ: 0.200000
# Phase 1, Epoch 340, Loss: 0.199438, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 350, Loss: 0.199399, λ: 0.200000
# Phase 1, Epoch 360, Loss: 0.199365, λ: 0.200000
# Phase 1, Epoch 370, Loss: 0.199334, λ: 0.200000
# Phase 1, Epoch 380, Loss: 0.199309, λ: 0.200000
# Phase 1, Epoch 390, Loss: 0.199285, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 400, Loss: 0.199266, λ: 0.200000
# Phase 1, Epoch 410, Loss: 0.199245, λ: 0.200000
# Phase 1, Epoch 420, Loss: 0.199226, λ: 0.200000
# Phase 1, Epoch 430, Loss: 0.199205, λ: 0.200000
# Phase 1, Epoch 440, Loss: 0.199184, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 1, Epoch 450, Loss: 0.199166, λ: 0.200000
# Phase 1, Epoch 460, Loss: 0.199145, λ: 0.200000
# Phase 1, Epoch 470, Loss: 0.199123, λ: 0.200000
# Phase 1, Epoch 480, Loss: 0.199101, λ: 0.200000
# Phase 1, Epoch 490, Loss: 0.199080, λ: 0.200000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 0, Loss: 0.198732, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 10, Loss: 0.198257, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 20, Loss: 0.198211, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 30, Loss: 0.198148, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 40, Loss: 0.198093, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 50, Loss: 0.198042, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 60, Loss: 0.197989, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 70, Loss: 0.197932, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 80, Loss: 0.197873, λ: 0.000000
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/train/train_pou_rbf.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Phase 2, Epoch 90, Loss: 0.197807, λ: 0.000000

# %%
x_train = normalizer.transform(x_train_raw)

visualize_final_approximation(
    model=model,
    params=final_params,
    x_train=x_train,
    y_train=y_train,
    normalizer=normalizer,
    ground_truth_fn=toy_func_2,
    save_path=None,   
    show_partitions=True,
    title="RBF-POU Approximation"
)
# Out:
# Debug: partitions_np.shape (300, 5)
# Debug: N = 300, C = 5
# /mnt/c/Users/chenwanxin/Documents/GitHub/thesis_project/utils/pou_utils.py:187: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Questions?
# + How to explain the "move"? It learn the feature of the functions(frenquency) with an initial guess? Really?
# + The POU weights learned in POU approximation is slightly different from the window functions in FBPINN.
# e.g., in the example: number of partitions = 5 on the interval [0, 8], POU weights is learned to find the disjoint partitions(but here in our example, we don't have discontinuities), the number of partitions should perfectly match. But the window functions are just to confine the neural networks, can be any number.
#
# we want the POU-approximation to provide guidance for domain decomposition, but the number of partitions is quite limited.（can be larger， like the perfectly matched number of partiions is 10, we can have 20）
